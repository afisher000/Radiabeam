# %%
import pandas as pd

df = pd.read_csv('../Scans/2024-07-26/2024-07-26-22-54-34 gain_curve.csv')

# %%
df.plot(kind='scatter', x='gain', y='sum')
# Out:
# <AxesSubplot: xlabel='gain', ylabel='sum'>

# %%
]
# Out:
# Index(['xc', 'yc', 'xrms', 'yrms', 'sum', 'filter_index', 'gain', 'exposure',
#        'camera', 'serial', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'x4', 'y4'],
#       dtype='object')
