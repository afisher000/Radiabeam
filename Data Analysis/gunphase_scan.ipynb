# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
directory = '../Scans/2024-08-13'

temp_path = os.path.join(directory, '12-59-40_gunphase_laseron.csv')
df_on = pd.read_csv(temp_path)

temp_path = os.path.join(directory, '13-01-23_gunphase_laseroff.csv')
df_off = pd.read_csv(temp_path)

# %%
plt.scatter(df_on.gunphase, df_on.charge)
# plt.scatter(df_on.gunphase, df_on['sum'])
# plt.scatter(df_off.gunphase, df_off['sum'])
