# %%
import pandas as pd
import numpy as np
import os

# %%
# Specify directory of csvs (saved from series)
quadscan_dir = '../Scans/2024-08-09/Quadscan'

# Read into dataframes
dfs = []
paths = [os.path.join(quadscan_dir, file) for file in os.listdir(quadscan_dir)]
dfs = [pd.read_csv(path) for path in paths]

# Combine and save to single csv file 
df = pd.concat(dfs, axis=0).reset_index(drop=True)

# %%
df
# Out:
#                timestamp  filter_index  gain  exposure camera         serial  \
# 0    2024-08-09 18-22-01             0    24      1000   Cam4  50-0536976126
# 1    2024-08-09 18-22-02             0    24      1000   Cam4  50-0536976126
# 2    2024-08-09 18-22-03             0    24      1000   Cam4  50-0536976126
# 3    2024-08-09 18-22-05             0    24      1000   Cam4  50-0536976126
# 4    2024-08-09 18-22-06             0    24      1000   Cam4  50-0536976126
# ..                   ...           ...   ...       ...    ...            ...
# 193  2024-08-09 18-39-05             0    23      1000   Cam4  50-0536976126
# 194  2024-08-09 18-39-06             0    23      1000   Cam4  50-0536976126
# 195  2024-08-09 18-39-07             0    23      1000   Cam4  50-0536976126
# 196  2024-08-09 18-39-08             0    23      1000   Cam4  50-0536976126
# 197  2024-08-09 18-39-10             0    23      1000   Cam4  50-0536976126
#
#      calibration  charge          xc          yc  ...      Y2      X3      Y3  \
# 0       0.009922  497.26  608.588117  701.594294  ...  0.9501 -0.2998 -0.0999
# 1       0.009922  503.60  598.415010  701.695214  ...  0.9501 -0.2998 -0.0999
# 2       0.009922  503.60  589.363639  699.865471  ...  0.9501 -0.2998 -0.0999
# 3       0.009922  494.11  601.955314  704.852772  ...  0.9501 -0.2998 -0.0999
# 4       0.009922  506.80  584.164115  700.005849  ...  0.9501 -0.2998 -0.0999
# ..           ...     ...         ...         ...  ...     ...     ...     ...
# 193     0.009922  494.11  628.558584  517.493217  ...  0.9501 -0.2998 -0.0999
# 194     0.009922  494.11  615.391832  567.566515  ...  0.9501 -0.2998 -0.0999
# 195     0.009922  503.60  602.485286  574.944180  ...  0.9501 -0.2998 -0.0999
# 196     0.009922  494.11  615.287910  564.986610  ...  0.9501 -0.2998 -0.0999
# 197     0.009922  494.11  599.355909  633.169589  ...  0.9501 -0.2998 -0.0999
#
#       X4   Y4      Q1      Q2   Q3      Q4      Q5
# 0    5.5  5.9  1.8001 -1.5998  1.6 -0.0011  0.0026
# 1    5.5  5.9  1.8001 -1.5998  1.6 -0.0011  0.0026
# 2    5.5  5.9  1.8001 -1.5998  1.6 -0.0011  0.0026
# 3    5.5  5.9  1.8001 -1.5998  1.6 -0.0011  0.0026
# 4    5.5  5.9  1.8001 -1.5998  1.6 -0.0011  0.0026
# ..   ...  ...     ...     ...  ...     ...     ...
# 193  5.5  5.9  0.8999 -0.4998  0.6 -0.0011  0.0026
# 194  5.5  5.9  0.8999 -0.4998  0.6 -0.0011  0.0026
# 195  5.5  5.9  0.8999 -0.4998  0.6 -0.0011  0.0026
# 196  5.5  5.9  0.8999 -0.4998  0.6 -0.0011  0.0026
# 197  5.5  5.9  0.8999 -0.4998  0.6 -0.0011  0.0026
#
# [198 rows x 32 columns]
